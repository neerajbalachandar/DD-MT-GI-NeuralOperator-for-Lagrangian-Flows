# %% [markdown]
# # Inspect Processed Data
#
# Quick checks for feature layout, pair splits, and stored train-only preprocessing statistics.

# %%
from pathlib import Path
import sys, numpy as np
FINAL = Path.cwd() / 'FLOW-reconstruction-in-VPM-using-FNO' / 'FINAL'
sys.path.insert(0, str(FINAL))
from gino.data.dataset import load_processed_dataset
data = load_processed_dataset(FINAL / '../../Processed_Data/processed_data_split3/particle_evolution_dataset.npz')
print('features:', data['feature_names'].tolist())
print('pairs train/val/test:', *(len(data[k]) for k in ('train_pair_ids','val_pair_ids','test_pair_ids')))
print('state order:', data['state_names'].tolist())
