# %% [markdown]
# A post processing tool to visualize the u and grad u predicted by the model in task 1, to be represented as a field data, in the analytically right way - using Biot-Savart law accelerated using FMM
